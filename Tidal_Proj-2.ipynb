# %%
# Out:
# Fitted coefficients:
# a1 (sin 12.42h): -0.5303590049745511
# b1 (cos 12.42h): 0.8705832866293757
# a2 (sin 24h):    2.5754987455417915
# b2 (cos 24h):    -0.7270290059721164
# c0 (offset):     2.5237866273639544
#
# Semidiurnal (12.42h): amplitude = 1.0194096002667434  phase (rad) = 2.117952806083183
# Diurnal (24h):        amplitude = 2.6761474107029577  phase (rad) = -0.2751278850587808
# /var/folders/nd/kqchyjwx31lfd3sdd83zlst40000gn/T/ipykernel_4463/711575819.py:5: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
# ...
